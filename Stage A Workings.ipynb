# %% [markdown]
# ## Stage A Workings
#
# My name is Stephanie Netoafomachukwu Anyama. Here are my workings for the Stage A quiz.

# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#reading the dataset into a dataframe
df = pd.read_csv('/Users/netoa/Downloads/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#To find the mean and standard deviations for year 2017
df.Y2017.describe()
# Out:
# count     59437.000000
# mean        140.917765
# std        1671.862359
# min       -1582.000000
# 25%           0.000000
# 50%           0.100000
# 75%           9.000000
# max      190873.000000
# Name: Y2017, dtype: float64

# %%
df.Element.unique()
# Out:
# array(['Total Population - Both sexes', 'Domestic supply quantity',
#        'Food supply (kcal/capita/day)',
#        'Protein supply quantity (g/capita/day)',
#        'Fat supply quantity (g/capita/day)', 'Production',
#        'Import Quantity', 'Stock Variation', 'Export Quantity', 'Feed',
#        'Seed', 'Losses', 'Processing', 'Other uses (non-food)',
#        'Residuals', 'Food', 'Food supply quantity (kg/capita/yr)',
#        'Tourist consumption'], dtype=object)

# %%
#To find the total amount of protein supplied by Madagascar in 2015
mad_protein = df.query('Element == "Protein supply quantity (g/capita/day)"')
mad_protein
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 3              4   Algeria       2901               Grand Total           674
# 6              4   Algeria       2903          Vegetal Products           674
# 9              4   Algeria       2941           Animal Products           674
# 25             4   Algeria       2905  Cereals - Excluding Beer           674
# 41             4   Algeria       2511        Wheat and products           674
# ...          ...       ...        ...                       ...           ...
# 60903        181  Zimbabwe       2769   Aquatic Animals, Others           674
# 60911        181  Zimbabwe       2775            Aquatic Plants           674
# 60921        181  Zimbabwe       2928             Miscellaneous           674
# 60931        181  Zimbabwe       2680               Infant food           674
# 60941        181  Zimbabwe       2899             Miscellaneous           674
#
# ...

# %%
mad = mad_protein.query('Area == "Madagascar"')
mad
# Out:
#        Area Code        Area  Item Code                      Item  \
# 30718        129  Madagascar       2901               Grand Total
# 30721        129  Madagascar       2903          Vegetal Products
# 30724        129  Madagascar       2941           Animal Products
# 30740        129  Madagascar       2905  Cereals - Excluding Beer
# 30756        129  Madagascar       2511        Wheat and products
# ...          ...         ...        ...                       ...
# 32113        129  Madagascar       2769   Aquatic Animals, Others
# 32123        129  Madagascar       2775            Aquatic Plants
# 32133        129  Madagascar       2928             Miscellaneous
# 32142        129  Madagascar       2680               Infant food
# 32152        129  Madagascar       2899             Miscellaneous
#
#        Element Code                                 Element          Unit  \
# 30718           674  Protein supply quantity (g/capita/day)  g/capita/day
# ...

# %%
mad.Y2015.sum()
# Out:
# 173.04999999999998

# %%
#To find element x=8 from these tuples
y = [(2, 4), (7, 8), (1, 5, 9)]
y[1][1]
# Out:
# 8

# %%
#To find the amount of wine produced in 2015 and 2018
df.groupby('Item').sum()
# Out:
# C:\Users\netoa\AppData\Local\Temp/ipykernel_24024/3872019965.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Item').sum()
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# ...

# %%
#my tuppy error
my_tuppy = (1,2,5,8)
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24024/3506354595.py in <module>
#       1 my_tuppy = (1,2,5,8)
# ----> 2 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Total number of unique countries
mad_protein.Area.nunique()
# Out:
# 45

# %%
#list to dataframe
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ['Age','Nationality','Overall']

df_x = pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])
df_x
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
#select from array
e = np.array([[94, 89, 63],[93, 92, 48],[92, 94, 56]])

# %%
e[:2,1:]
# Out:
# array([[89, 63],
#        [92, 48]])

# %%
#sum of Processing in 2017, highest sum of Stock Variation
df.groupby('Element').sum()
# Out:
# C:\Users\netoa\AppData\Local\Temp/ipykernel_24024/1487255084.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Element').sum()
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# ...

# %%
df.shape
# Out:
# (60943, 12)

# %%
#Sums and Areas
df_a = df.groupby('Area').sum().sort_values(by='Y2017')
df_a
# Out:
# C:\Users\netoa\AppData\Local\Temp/ipykernel_24024/3552838256.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_a = df.groupby('Area').sum().sort_values(by='Y2017')
#                              Area Code  Item Code  Element Code       Y2014  \
# Area
# Sudan (former)                   10918     146631        286940        0.00
# Ethiopia PDR                      2418     107853        209609        0.00
# Comoros                           2025     124514        241681       32.00
# Seychelles                       13328     188266        367816      305.20
# Sao Tome and Principe           227161    3168050       4260866    12458.64
# Cabo Verde                       44100    3396746       4787751    14576.94
# Guinea-Bissau                   197400    3035574       4011694    17708.67
# ...

# %%
#Missing data in 2014
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
#least correlation to Element Code
corr_matrix = df.corr()
sb.heatmap(corr_matrix, annot=True)
plt.show()
# Out:
# C:\Users\netoa\AppData\Local\Temp/ipykernel_24024/371406577.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
